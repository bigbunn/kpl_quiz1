# %% [markdown]
# # Quiz Project Streamlit:
# - **Nama:** Muhammad Syaibani Al Hakim
# - **Dataset:** Dataset Salary berisi kolom tahun pengalaman dan salary yang didapatkan. Sumber : https://www.kaggle.com/datasets/abhishek14398/salary-dataset-simple-linear-regression?resource=download

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana prediksi salary seseorang berdasarkan pengalamannya?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
data=pd.read_csv("/Salary_dataset.csv")
#conversion into data frame

# %% [markdown]
# ### Assessing Data

# %%
df=pd.DataFrame(data,columns=["YearsExperience","Salary"])
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
df.shape
# Out:
# (30, 2)

# %%
df.isna().any()
# Out:
# YearsExperience    False
# Salary             False
# dtype: bool

# %% [markdown]
# ### Cleaning Data

# %%
#data already clean

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
fig=px.scatter(df,x="YearsExperience",y="Salary")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana prediksi salary seseorang berdasarkan pengalamannya?

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Pertanyaan 1 : Bagaimana prediksi salary seseorang berdasarkan pengalamannya?
